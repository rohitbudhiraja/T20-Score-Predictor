# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

from tqdm import tqdm

from yaml import safe_load

# %%
from cricsummary import Duranz

# %%
import os
import glob
from cricsummary import yaml_to_csv

# %%
filenames = []
for file in os.listdir(r'D:\Data Analytics Notes\Pr\T20 Project\t20s'):
    filenames.append(os.path.join(r'D:\Data Analytics Notes\Pr\T20 Project\t20s',file))

# %%
filenames[0:5]
# Out:
# ['D:\\Data Analytics Notes\\Pr\\T20 Project\\t20s\\1001349.yaml',
#  'D:\\Data Analytics Notes\\Pr\\T20 Project\\t20s\\1001351.yaml',
#  'D:\\Data Analytics Notes\\Pr\\T20 Project\\t20s\\1001353.yaml',
#  'D:\\Data Analytics Notes\\Pr\\T20 Project\\t20s\\1004729.yaml',
#  'D:\\Data Analytics Notes\\Pr\\T20 Project\\t20s\\1007655.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
# 100%|█████████▉| 1746/1747 [12:48<00:00,  2.27it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-792532c74aef> in <module>
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = final_df.append(df)
#
# D:\Data Science\Anaconda\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# ...

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 0   [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
# ...

# %%
df= final_df[['innings','info.dates','info.gender','info.match_type','info.outcome.winner','info.overs','info.player_of_match','info.teams','info.toss.decision','info.toss.winner','info.venue','match_id','info.city']]

# %%
df.head()
# Out:
#                                              innings    info.dates  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0  [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0  [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
#
#   info.gender info.match_type info.outcome.winner  info.overs  \
# 0        male             T20           Sri Lanka          20
# 0        male             T20           Sri Lanka          20
# 0        male             T20           Australia          20
# 0        male             T20           Hong Kong          20
# 0        male             T20            Zimbabwe          20
#
#   info.player_of_match              info.teams info.toss.decision  \
# 0      [DAS Gunaratne]  [Australia, Sri Lanka]              field
# ...

# %%
backup_final=df.copy()

# %%
df['info.gender'].value_counts()
# Out:
# male      1192
# female     554
# Name: info.gender, dtype: int64

# %%
df = df[df['info.gender'] == 'male']
df.drop(columns=['info.gender'],inplace=True)
df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0              T20           Sri Lanka          20      [DAS Gunaratne]
# ...

# %%
df['info.overs'].value_counts()
# Out:
# 20    1189
# 50       3
# Name: info.overs, dtype: int64

# %%
df['info.match_type'].value_counts()
# Out:
# T20    1192
# Name: info.match_type, dtype: int64

# %%
df['info.overs'].value_counts()
# Out:
# 20    1189
# 50       3
# Name: info.overs, dtype: int64

# %%
df = df[df['info.overs'] == 20]
df.drop(columns=['info.overs','info.match_type'],inplace=True)
df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.outcome.winner info.player_of_match  \
# 0            Sri Lanka      [DAS Gunaratne]
# 0            Sri Lanka      [DAS Gunaratne]
# ...

# %%
import pickle
pickle.dump(df,open('dataset_level1.pkl','wb'))

# %%
#matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121      1190    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122      1190    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123      1190    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124      1190    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125      1190    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania',
#        'Luxembourg', 'Austria', 'Czech Republic', 'Greece', 'Serbia',
#        'Malta', 'France', 'Sweden', 'Rwanda', 'Finland', 'Hungary',
#        'Estonia', 'Cyprus', 'Switzerland', 'Swaziland', 'Seychelles',
# ...

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka',
    'Scotland',
    'Namibia',
    'Ireland',
    'Zimbabwe',
    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121      1190    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122      1190    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123      1190    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124      1190    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125      1190    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121      1190    Sri Lanka    Australia  19.3     1                0  Colombo
# 122      1190    Sri Lanka    Australia  19.4     0                0  Colombo
# 123      1190    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124      1190    Sri Lanka    Australia  19.6     2                0  Colombo
# 125      1190    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
df = output.copy()

# %%
df.isnull().sum()
# Out:
# match_id                0
# batting_team            0
# bowling_team            0
# ball                    0
# runs                    0
# player_dismissed        0
# city                13102
# venue                   0
# dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#                       venue
# 0  Melbourne Cricket Ground
# 1  Melbourne Cricket Ground
# 2  Melbourne Cricket Ground
# 3  Melbourne Cricket Ground
# 4  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]


df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score
# 0              0
# 1              0
# 2              1
# 3              3
# 4              3

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score
# 0              0
# 1              0
# 2              1
# 3              3
# 4              3

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score
# 0              0
# 1              0
# 2              1
# 3              3
# 4              3

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
# 2         2    Australia    Sri Lanka   0.3     1                0  Melbourne
# 3         2    Australia    Sri Lanka   0.4     2                0  Melbourne
# 4         2    Australia    Sri Lanka   0.5     0                0  Melbourne
#
#    current_score over ball_no
# 0              0    0       1
# 1              0    0       2
# 2              1    0       3
# 3              3    0       4
# 4              3    0       5

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df.head(2)
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
#
#    current_score over ball_no  balls_bowled
# 0              0    0       1             1
# 1              0    0       2             2

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df.head(2)
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed       city  \
# 0         2    Australia    Sri Lanka   0.1     0                0  Melbourne
# 1         2    Australia    Sri Lanka   0.2     0                0  Melbourne
#
#    current_score over ball_no  balls_bowled  balls_left
# 0              0    0       1             1         119
# 1              0    0       2             2         118

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121      1190    Sri Lanka    Australia  19.3     1                 8
# 122      1190    Sri Lanka    Australia  19.4     0                 8
# 123      1190    Sri Lanka    Australia  19.5     0                 9
# 124      1190    Sri Lanka    Australia  19.6     2                 9
# 125      1190    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df.head(2)
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         2    Australia    Sri Lanka   0.1     0                 0
# 1         2    Australia    Sri Lanka   0.2     0                 0
#
#         city  current_score over ball_no  balls_bowled  balls_left  \
# 0  Melbourne              0    0       1             1         119
# 1  Melbourne              0    0       2             2         118
#
#    wickets_left  crr
# 0            10  0.0
# 1            10  0.0

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team  bowling_team       city  current_score  balls_left  \
# 63694  New Zealand  South Africa  Centurion             46          89
# 27951  West Indies  South Africa      Dubai             44          83
#
#        wickets_left       crr  last_five  runs_x
# 63694            10  8.903226       42.0     177
# 27951            10  7.135135       40.0     143

# %% [markdown]
# # Model Building

# %%
X = final_df.drop(columns=['runs_x'])
Y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=100)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import r2_score,mean_absolute_error

# %%
train=pd.concat([Y_train,X_train],axis=1) #concating train data

# %%
step1 = ColumnTransformer([
    ('step1',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
step2 = RandomForestRegressor(n_estimators=100,
                              random_state=100,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

# %%
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

Y_pred = pipe.predict(X_test)

print(r2_score(Y_test,Y_pred))
print(mean_absolute_error(Y_test,Y_pred))
# Out:
# 0.8847420374553145
# 7.784687103881554

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Dubai',
#  'Johannesburg',
#  'Mirpur',
#  'Harare',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Dhaka',
#  'Abu Dhabi',
#  'Pallekele',
#  'Barbados',
#  'Wellington',
#  'Durban',
#  'Melbourne',
#  'St Lucia',
#  'Nottingham',
#  'Hamilton',
#  'Sydney',
#  'Centurion',
#  'Sharjah',
#  'Lahore',
#  'Manchester',
#  'Lauderhill',
#  'Nagpur',
#  'Southampton',
#  'Mumbai',
#  'Cardiff',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Hambantota',
#  'Gros Islet',
#  "St George's",
#  'Dublin',
#  'Edinburgh',
#  'Greater Noida',
#  'Delhi',
#  'Christchurch',
#  'Trinidad',
#  'Guyana',
#  'Bready',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Ahmedabad']
